# %% [markdown]
# #Discreat Probability distribution

# %% [markdown]
# ##Binomial Distribution

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
num_trails = 10
heads_prob = .5
probs = [binom.pmf(i,num_trails,heads_prob) for i in range(11)]
plt.stem(list(range(11)),probs)
plt.show()

# %% [markdown]
# ##Poisson Distribution

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
rate=3.3
probs = [poisson.pmf(i,rate) for i in range(20)]
plt.stem(list(range(20)),probs)
plt.show()

# %% [markdown]
# ##Bernouli distribution

# %%
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
probabilty=0.8
x=[0,1]
probs = bernoulli.pmf(x,probabilty)
plt.bar(x,probs)
plt.title("Bernoulli Distribution")
plt.xlabel("x")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# #Continous Probability Distribution

# %% [markdown]
# ##Normal Distribution

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-4,4, 1000)
y=norm.pdf(x,0,1)
plt.stem(x,y)
plt.show()

# %% [markdown]
# ##Exponential Distribution

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10, 1000)
y=expon.pdf(x,0,1)
plt.stem(x,y)
plt.show()
